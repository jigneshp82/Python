# %%
import pandas as pd
import tabula as t

# %%
df = t.read_pdf("/home/jignesh/Documents/Python/campaign_donors.pdf",pages = "all")

# %%
print (df)
# Out:
# [                       Apellido Nombre  Unnamed: 0   Matricula           Cuit  \
# 0                     MENA JUAN MARTÍN         NaN  27.083.460  20-27083460-5
# 1                         MOLLE MATÍAS         NaN  25.348.547  20-25348547-8
# 2               MOLLEVI FEDERICO OSCAR         NaN  25.028.246  20-25028246-0
# 3                 PERAZZO PABLO DANIEL         NaN  25.348.394  20-25348394-7
# 4               PICARDI FRANCO EDUARDO         NaN  27.382.271  20-27382271-3
# 5                PISONI CARLOS ENRIQUE         NaN  26.034.823  20-26034823-0
# 6               PONTORIERO MARÍA PAULA         NaN  23.249.597  27-23249597-4
# 7                 PULESTON JUAN MIGUEL         NaN  11.895.661  20-11895661-4
# 8                   REMÓN MABEL AURORA         NaN  11.292.939  27-11292939-3
# 9                  SARRABAYROUSE DIEGO         NaN  24.662.899  20-24662899-9
# 10               SPATOLA ANALÍA CARMEN         NaN  24.560.922  27-24560922-7
# ...

# %%
t.convert_into("/home/jignesh/Documents/Python/campaign_donors.pdf","/home/jignesh/Documents/Python/cd.csv",output_format="csv", pages= "all")
